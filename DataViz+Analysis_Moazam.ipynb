# %%
import pandas as pd
import numpy as np

# %%
import aqi
myaqi = aqi.to_aqi([
    (aqi.POLLUTANT_PM25, '35.9')
])
print(myaqi)
# Out:
# 102

# %%
# Read feather file
df = pd.read_feather('export_UIUC_feather', columns=None, use_threads=True)
df=df.drop(['index'], axis=1)
df
# Out:
#         reading_datestamp  co_prescaled  CO2_prescaled  no_prescaled  \
# 0     2021-09-02 04:45:00        250.38         420.35         15.87
# 1     2021-09-02 05:00:00        255.19         418.04         15.78
# 2     2021-09-02 05:15:00        254.69         413.88         15.90
# 3     2021-09-02 05:30:00        265.17         412.49         15.54
# 4     2021-09-02 05:45:00        256.95         408.79         17.10
# ...                   ...           ...            ...           ...
# 8540  2021-11-30 14:00:00        300.71         776.00          3.34
# 8541  2021-11-30 14:15:00        303.22         775.16          2.44
# 8542  2021-11-30 14:30:00        313.67         776.00          3.17
# 8543  2021-11-30 14:45:00        309.89         776.85          5.20
# 8544  2021-11-30 15:00:00        310.97         779.41          2.85
#
#       no2_prescaled  o3_prescaled  pm1_prescale  pm2_5_prescale  pm4_prescale  \
# 0              6.86         14.86          5.38            6.94          8.00
# 1              7.10         16.61          5.26            6.89          7.97
# 2              7.30         18.42          5.35            6.98          8.12
# 3              7.48         20.59          5.20            6.77          7.84
# 4              6.56         23.36          5.40            6.97          8.12
# ...             ...           ...           ...             ...           ...
# 8540           5.50         30.32          3.20            4.52          5.50
# 8541           5.20         29.64          3.21            4.38          5.31
# 8542           5.35         29.84          3.20            4.41          5.38
# 8543           4.53         33.18          3.15            4.51          5.44
# 8544           5.16         30.92          3.18            4.46          5.68
#
#       pm10_prescale  pm_total_prescale  pm_tpc_prescale  nox_prescaled  \
# 0             10.23              10.23             2.91          13.14
# 1              9.76               9.76             2.82          12.58
# 2             11.68              11.70             2.88          14.58
# 3              9.82               9.82             2.78          12.60
# 4             10.32              10.32             2.92          13.24
# ...             ...                ...              ...            ...
# 8540           9.11               9.11             1.83           8.84
# 8541           9.70               9.72             1.81           7.64
# 8542           9.14               9.14             1.82           8.52
# 8543           8.46               8.46             1.79           9.73
# 8544          11.58              11.61             1.82           8.01
#
#       temperature_f  pressure  humidity
# 0              75.9     992.6      63.6
# 1              77.0     992.5      62.5
# 2              77.7     993.0      61.5
# 3              78.4     992.3      61.0
# 4              79.2     992.9      59.8
# ...             ...       ...       ...
# 8540           54.3     992.7      58.5
# 8541           54.1     992.9      58.8
# 8542           54.0     992.9      58.8
# 8543           53.6     992.9      58.8
# 8544           53.4     992.4      59.0
#
# [8545 rows x 16 columns]

# %%
df['reading_datestamp'] = pd.to_datetime(df['reading_datestamp'])
# set a column as the index
df.set_index('reading_datestamp', inplace=True)
df.head()
# Out:
#                      co_prescaled  CO2_prescaled  no_prescaled  no2_prescaled  \
# reading_datestamp
# 2021-09-02 04:45:00        250.38         420.35         15.87           6.86
# 2021-09-02 05:00:00        255.19         418.04         15.78           7.10
# 2021-09-02 05:15:00        254.69         413.88         15.90           7.30
# 2021-09-02 05:30:00        265.17         412.49         15.54           7.48
# 2021-09-02 05:45:00        256.95         408.79         17.10           6.56
#
#                      o3_prescaled  pm1_prescale  pm2_5_prescale  pm4_prescale  \
# reading_datestamp
# 2021-09-02 04:45:00         14.86          5.38            6.94          8.00
# 2021-09-02 05:00:00         16.61          5.26            6.89          7.97
# 2021-09-02 05:15:00         18.42          5.35            6.98          8.12
# 2021-09-02 05:30:00         20.59          5.20            6.77          7.84
# 2021-09-02 05:45:00         23.36          5.40            6.97          8.12
#
#                      pm10_prescale  pm_total_prescale  pm_tpc_prescale  \
# reading_datestamp
# 2021-09-02 04:45:00          10.23              10.23             2.91
# 2021-09-02 05:00:00           9.76               9.76             2.82
# 2021-09-02 05:15:00          11.68              11.70             2.88
# 2021-09-02 05:30:00           9.82               9.82             2.78
# 2021-09-02 05:45:00          10.32              10.32             2.92
#
#                      nox_prescaled  temperature_f  pressure  humidity
# reading_datestamp
# 2021-09-02 04:45:00          13.14           75.9     992.6      63.6
# 2021-09-02 05:00:00          12.58           77.0     992.5      62.5
# 2021-09-02 05:15:00          14.58           77.7     993.0      61.5
# 2021-09-02 05:30:00          12.60           78.4     992.3      61.0
# 2021-09-02 05:45:00          13.24           79.2     992.9      59.8

# %%
df['CO2_prescaled'].plot(figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='reading_datestamp'>

# %%
df[['pm2_5_prescale']].resample('1D').mean().plot(figsize=(15,5), kind='line')
# Out:
# <AxesSubplot:xlabel='reading_datestamp'>

# %%
df_urbanaOH = pd.read_feather('export_UrbanaOnHolmes_feather', columns=None, use_threads=True)
df_urbanaOH['new_date'] = pd.to_datetime(df_urbanaOH['new_date'])
df_urbanaOH=df_urbanaOH[['new_date','PM2.5 (CF=1) ug/m3']]
df_urbanaOH = df_urbanaOH.rename({'new_date': 'reading_datestamp','PM2.5 (CF=1) ug/m3': 'pm2.5_UrbanaOH' }, axis=1)
df_urbanaOH.set_index('reading_datestamp', inplace=True)
#df_urbanaOH
df_urbanaOH = df_urbanaOH[df_urbanaOH.index.isin(df.index)]

df_urbana = pd.read_feather('export_Urbana_feather', columns=None, use_threads=True)
df_urbana['new_date'] = pd.to_datetime(df_urbana['new_date'])
df_urbana=df_urbana[['new_date','PM2.5 (CF=1) ug/m3']]
df_urbana = df_urbana.rename({'new_date': 'reading_datestamp','PM2.5 (CF=1) ug/m3': 'pm2.5_Urbana' }, axis=1)
df_urbana.set_index('reading_datestamp', inplace=True)
# df_urbana
df_urbana = df_urbana[df_urbana.index.isin(df.index)]

df_champaign = pd.read_feather('export_WarnowChacko_feather', columns=None, use_threads=True)
df_champaign['new_date'] = pd.to_datetime(df_champaign['new_date'])
df_champaign=df_champaign[['new_date','PM2.5 (CF=1) ug/m3']]
df_champaign = df_champaign.rename({'new_date': 'reading_datestamp','PM2.5 (CF=1) ug/m3': 'pm2.5_Champaign' }, axis=1)
df_champaign.set_index('reading_datestamp', inplace=True)
# df_champaign
df_champaign = df_champaign[df_champaign.index.isin(df.index)]

combined_urbana= pd.merge(df_urbanaOH,df_urbana, on='reading_datestamp')
merged= pd.merge(df,combined_urbana, on='reading_datestamp')

# %%
merged
# Out:
#                      co_prescaled  CO2_prescaled  no_prescaled  no2_prescaled  \
# reading_datestamp
# 2021-09-02 04:45:00        250.38         420.35         15.87           6.86
# 2021-09-02 05:00:00        255.19         418.04         15.78           7.10
# 2021-09-02 05:15:00        254.69         413.88         15.90           7.30
# 2021-09-02 05:30:00        265.17         412.49         15.54           7.48
# 2021-09-02 05:45:00        256.95         408.79         17.10           6.56
# ...                           ...            ...           ...            ...
# 2021-11-28 07:45:00        447.65         788.77          0.34          19.31
# 2021-11-28 08:00:00        441.91         785.37          0.41          18.66
# 2021-11-28 08:15:00        438.15         786.21          0.35          17.80
# 2021-11-28 08:30:00        429.60         788.77          0.84          18.49
# 2021-11-28 08:45:00        429.78         784.52          2.94          20.04
#
#                      o3_prescaled  pm1_prescale  pm2_5_prescale  pm4_prescale  \
# reading_datestamp
# 2021-09-02 04:45:00         14.86          5.38            6.94          8.00
# 2021-09-02 05:00:00         16.61          5.26            6.89          7.97
# 2021-09-02 05:15:00         18.42          5.35            6.98          8.12
# 2021-09-02 05:30:00         20.59          5.20            6.77          7.84
# 2021-09-02 05:45:00         23.36          5.40            6.97          8.12
# ...                           ...           ...             ...           ...
# 2021-11-28 07:45:00         14.74          4.86            6.66          8.39
# 2021-11-28 08:00:00         15.02          4.62            6.44          7.98
# 2021-11-28 08:15:00         15.02          4.76            6.56          8.26
# 2021-11-28 08:30:00         14.68          4.58            6.41          8.20
# 2021-11-28 08:45:00         16.24          4.71            6.77          8.38
#
#                      pm10_prescale  pm_total_prescale  pm_tpc_prescale  \
# reading_datestamp
# 2021-09-02 04:45:00          10.23              10.23             2.91
# 2021-09-02 05:00:00           9.76               9.76             2.82
# 2021-09-02 05:15:00          11.68              11.70             2.88
# 2021-09-02 05:30:00           9.82               9.82             2.78
# 2021-09-02 05:45:00          10.32              10.32             2.92
# ...                            ...                ...              ...
# 2021-11-28 07:45:00          14.06              14.09             2.65
# 2021-11-28 08:00:00          13.92              13.95             2.56
# 2021-11-28 08:15:00          14.31              14.33             2.63
# 2021-11-28 08:30:00          12.28              12.28             2.54
# 2021-11-28 08:45:00          12.92              12.92             2.62
#
#                      nox_prescaled  temperature_f  pressure  humidity  \
# reading_datestamp
# 2021-09-02 04:45:00          13.14           75.9     992.6      63.6
# 2021-09-02 05:00:00          12.58           77.0     992.5      62.5
# 2021-09-02 05:15:00          14.58           77.7     993.0      61.5
# 2021-09-02 05:30:00          12.60           78.4     992.3      61.0
# 2021-09-02 05:45:00          13.24           79.2     992.9      59.8
# ...                            ...            ...       ...       ...
# 2021-11-28 07:45:00          19.65           30.9     991.5      75.5
# 2021-11-28 08:00:00          19.07           31.5     991.8      75.5
# 2021-11-28 08:15:00          18.15           32.0     991.8      75.0
# 2021-11-28 08:30:00          19.33           32.5     991.9      74.9
# 2021-11-28 08:45:00          22.98           33.3     992.6      74.6
#
#                      pm2.5_UrbanaOH  pm2.5_Urbana
# reading_datestamp
# 2021-09-02 04:45:00        8.567143      7.600000
# 2021-09-02 05:00:00        9.157500      8.282857
# 2021-09-02 05:15:00        9.065714      8.436250
# 2021-09-02 05:30:00        9.797500      8.907143
# 2021-09-02 05:45:00        9.164286      9.141250
# ...                             ...           ...
# 2021-11-28 07:45:00       17.158750     15.065714
# 2021-11-28 08:00:00       17.278571     15.300000
# 2021-11-28 08:15:00       17.271250     15.505714
# 2021-11-28 08:30:00       16.630000     15.695000
# 2021-11-28 08:45:00       16.998000     15.471429
#
# [8316 rows x 17 columns]

# %%
df_aqi = merged.copy()
def val_to_aqi(pollutant,input_col):
    # Supported  by AQI library
    #pm10 (µg/m³), o3_8h (ppm), co_8h (ppm), no2_1h (ppb), o3_1h (ppm), so2_1h (ppb), pm25 (µg/m³)
    temp=[]
    for i in input_col.tolist():
        cal_aqi = int(aqi.to_aqi([(getattr(aqi, pollutant), i)]))
        temp.append(cal_aqi)
    return temp

df_aqi['AQI_UrbanaOH']=val_to_aqi('POLLUTANT_PM25', df_aqi['pm2.5_UrbanaOH'])
df_aqi['AQI_Urbana']=val_to_aqi('POLLUTANT_PM25', df_aqi['pm2.5_Urbana'])
df_aqi_purple= df_aqi[['AQI_UrbanaOH','AQI_Urbana']].copy()
df_aqi_purple
# Out:
#                      AQI_UrbanaOH  AQI_Urbana
# reading_datestamp
# 2021-09-02 04:45:00            35          31
# 2021-09-02 05:00:00            38          34
# 2021-09-02 05:15:00            38          35
# 2021-09-02 05:30:00            40          37
# 2021-09-02 05:45:00            38          38
# ...                           ...         ...
# 2021-11-28 07:45:00            62          57
# 2021-11-28 08:00:00            62          58
# 2021-11-28 08:15:00            62          58
# 2021-11-28 08:30:00            60          58
# 2021-11-28 08:45:00            61          58
#
# [8316 rows x 2 columns]

# %%
def combined_aqi(readings):
    vals= readings[1:5]
    if all(i >= 0 for i in vals):
        myaqi = aqi.to_aqi([
        (aqi.POLLUTANT_CO_8H, readings[1]),
        (aqi.POLLUTANT_NO2_1H, readings[2]),
        (aqi.POLLUTANT_O3_8H, readings[3]),
        (aqi.POLLUTANT_PM10, readings[4]),
        (aqi.POLLUTANT_PM25, readings[5])
         ])
    else:
        myaqi = aqi.to_aqi([
        (aqi.POLLUTANT_CO_8H, readings[1]),
        (aqi.POLLUTANT_O3_8H, readings[3]),
        (aqi.POLLUTANT_PM10, readings[4]),
        (aqi.POLLUTANT_PM25, readings[5])
         ])
    return int(myaqi)
df_aqi = merged[['co_prescaled','no2_prescaled','o3_prescaled','pm10_prescale','pm2_5_prescale']].copy()
df_aqi= df_aqi.dropna()
df_aqi.reset_index(level=0, inplace=True)
df_aqi['co_prescaled']= df_aqi['co_prescaled']/1000
df_aqi['o3_prescaled']=df_aqi['o3_prescaled']/1000

for i in df_aqi.index.values.tolist():
    df_aqi.loc[i,'combAQI'] = combined_aqi(df_aqi.iloc[i].tolist())

# %%
df_aqi.set_index('reading_datestamp', inplace=True)
df_aqi_uiuc=df_aqi[['combAQI']].copy()
df_aqi_uiuc
# Out:
#                      combAQI
# reading_datestamp
# 2021-09-02 04:45:00     29.0
# 2021-09-02 05:00:00     28.0
# 2021-09-02 05:15:00     29.0
# 2021-09-02 05:30:00     28.0
# 2021-09-02 05:45:00     29.0
# ...                      ...
# 2021-11-28 07:45:00     28.0
# 2021-11-28 08:00:00     27.0
# 2021-11-28 08:15:00     27.0
# 2021-11-28 08:30:00     27.0
# 2021-11-28 08:45:00     28.0
#
# [8290 rows x 1 columns]

# %%
AQI_combined= pd.merge(df_aqi_uiuc,df_aqi_purple, on='reading_datestamp')
AQI_combined
# Out:
#                      combAQI  AQI_UrbanaOH  AQI_Urbana
# reading_datestamp
# 2021-09-02 04:45:00     29.0            35          31
# 2021-09-02 05:00:00     28.0            38          34
# 2021-09-02 05:15:00     29.0            38          35
# 2021-09-02 05:30:00     28.0            40          37
# 2021-09-02 05:45:00     29.0            38          38
# ...                      ...           ...         ...
# 2021-11-28 07:45:00     28.0            62          57
# 2021-11-28 08:00:00     27.0            62          58
# 2021-11-28 08:15:00     27.0            62          58
# 2021-11-28 08:30:00     27.0            60          58
# 2021-11-28 08:45:00     28.0            61          58
#
# [8298 rows x 3 columns]

# %%
# Incomplete

df_aqi = merged[['co_prescaled','no2_prescaled','o3_prescaled','pm10_prescale','pm2_5_prescale']].copy()
df_aqi= df_aqi.dropna()
df_aqi.reset_index(level=0, inplace=True)
df_aqi['co_prescaled']= df_aqi['co_prescaled']/1000
df_aqi['o3_prescaled']=df_aqi['o3_prescaled']/1000

df_covertedAQI = pd.DataFrame()
df_covertedAQI['AQI_CO']=val_to_aqi('POLLUTANT_CO_8H', df_aqi['co_prescaled'])
df_covertedAQI['AQI_NO2']=val_to_aqi('POLLUTANT_NO2_1H', df_aqi['no2_prescaled'])
df_covertedAQI['AQI_O3']=val_to_aqi('POLLUTANT_O3_8H', df_aqi['o3_prescaled'])
df_covertedAQI
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/_m/f21vn7kj1b38wtjf1qn7m6kh0000gq/T/ipykernel_1056/4136696757.py in <module>
#       7 df_covertedAQI = pd.DataFrame()
#       8 df_covertedAQI['AQI_CO']=val_to_aqi('POLLUTANT_CO_8H', df_aqi['co_prescaled'])
# ----> 9 df_covertedAQI['AQI_NO2']=val_to_aqi('POLLUTANT_NO2_1H', df_aqi['no2_prescaled'])
#      10 df_covertedAQI['AQI_O3']=val_to_aqi('POLLUTANT_O3_8H', df_aqi['o3_prescaled'])
#      11 df_covertedAQI
#
# /var/folders/_m/f21vn7kj1b38wtjf1qn7m6kh0000gq/T/ipykernel_1056/409880307.py in val_to_aqi(pollutant, input_col)
#       5     temp=[]
#       6     for i in input_col.tolist():
# ----> 7         cal_aqi = int(aqi.to_aqi([(getattr(aqi, pollutant), i)]))
#       8         temp.append(cal_aqi)
#       9     return temp
#
# /opt/anaconda3/envs/dataviz/lib/python3.9/site-packages/aqi/__init__.py in to_aqi(ccs, algo)
#      43     """
#      44     _aqi = get_algo(algo)
# ---> 45     return _aqi.aqi(ccs)
#      46
#      47 def to_cc(elem, iaqi, algo=ALGO_EPA):
#
# /opt/anaconda3/envs/dataviz/lib/python3.9/site-packages/aqi/algos/base.py in aqi(self, ccs, iaqis)
#      34         _iaqis = {}
#      35         for (elem, cc) in ccs:
# ---> 36             _iaqi = self.iaqi(elem, cc)
#      37             if _iaqi is not None:
#      38                 _iaqis[elem] = _iaqi
#
# /opt/anaconda3/envs/dataviz/lib/python3.9/site-packages/aqi/algos/base.py in iaqi(self, elem, cc)
#      89             idx += 1
#      90         # get corresponding AQI boundaries
# ---> 91         (aqilo, aqihi) = self.piecewise['aqi'][idx]
#      92
#      93         # equation
#
# IndexError: list index out of range

# %%
def get_label(val):
    if val <=50:
        label = "Good"
    elif val>=51 and val<=100:
        label = 'Moderate'
    elif val>=101 and val<=150:
        label = 'Unhealthy for Sensitive Groups'
    elif val>=151 and val<=200:
        label = 'Unhealthy'
    else:
        label = "Very Unhealthy"
    return label

AQI_combined['combAQI_c']= [get_label(val) for val in AQI_combined['combAQI']]
AQI_combined['AQI_UrbanaOH_c']= [get_label(val) for val in AQI_combined['AQI_UrbanaOH']]
AQI_combined['AQI_Urbana_c']= [get_label(val) for val in AQI_combined['AQI_Urbana']]
AQI_combined
# Out:
#                      combAQI  AQI_UrbanaOH  AQI_Urbana combAQI_c  \
# reading_datestamp
# 2021-09-02 04:45:00     29.0            35          31      Good
# 2021-09-02 05:00:00     28.0            38          34      Good
# 2021-09-02 05:15:00     29.0            38          35      Good
# 2021-09-02 05:30:00     28.0            40          37      Good
# 2021-09-02 05:45:00     29.0            38          38      Good
# ...                      ...           ...         ...       ...
# 2021-11-28 07:45:00     28.0            62          57      Good
# 2021-11-28 08:00:00     27.0            62          58      Good
# 2021-11-28 08:15:00     27.0            62          58      Good
# 2021-11-28 08:30:00     27.0            60          58      Good
# 2021-11-28 08:45:00     28.0            61          58      Good
#
#                     AQI_UrbanaOH_c AQI_Urbana_c
# reading_datestamp
# 2021-09-02 04:45:00           Good         Good
# 2021-09-02 05:00:00           Good         Good
# 2021-09-02 05:15:00           Good         Good
# 2021-09-02 05:30:00           Good         Good
# 2021-09-02 05:45:00           Good         Good
# ...                            ...          ...
# 2021-11-28 07:45:00       Moderate     Moderate
# 2021-11-28 08:00:00       Moderate     Moderate
# 2021-11-28 08:15:00       Moderate     Moderate
# 2021-11-28 08:30:00       Moderate     Moderate
# 2021-11-28 08:45:00       Moderate     Moderate
#
# [8298 rows x 6 columns]

# %%
colors = ['purple',  'red', 'orange', 'yellow', 'green']
orders = ['Very Unhealthy', 'Unhealthy', 'Unhealthy for Sensitive Groups', 'Moderate', 'Good']
colormap = dict(zip(orders, colors))
colormap
# Out:
# {'Very Unhealthy': 'purple',
#  'Unhealthy': 'red',
#  'Unhealthy for Sensitive Groups': 'orange',
#  'Moderate': 'yellow',
#  'Good': 'green'}

# %%
AQI_combined['AQI_Urbana'].value_counts()
# Out:
# 12     186
# 10     178
# 52     167
# 15     158
# 8      154
#       ...
# 125      1
# 123      1
# 100      1
# 120      1
# 149      1
# Name: AQI_Urbana, Length: 163, dtype: int64

# %%
sns.scatterplot(data=AQI_combined, x=AQI_combined.index.week, y=AQI_combined['AQI_Urbana'],
                hue='AQI_Urbana_c', palette=colormap, alpha=0.8)
# Out:
# /var/folders/_m/f21vn7kj1b38wtjf1qn7m6kh0000gq/T/ipykernel_32459/1111994114.py:1: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series.  To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   sns.scatterplot(data=AQI_combined, x=AQI_combined.index.week, y=AQI_combined['AQI_Urbana'],
# <AxesSubplot:xlabel='reading_datestamp', ylabel='AQI_Urbana'>

# %%
sns.scatterplot(data=AQI_combined, x=AQI_combined.index.week, y=AQI_combined['combAQI'],
                hue='combAQI_c', palette=colormap, alpha=0.8)
# Out:
# /var/folders/_m/f21vn7kj1b38wtjf1qn7m6kh0000gq/T/ipykernel_32459/2723643246.py:1: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series.  To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   sns.scatterplot(data=AQI_combined, x=AQI_combined.index.week, y=AQI_combined['combAQI'],
# <AxesSubplot:xlabel='reading_datestamp', ylabel='combAQI'>

# %%
sns.scatterplot(data=AQI_combined, x=AQI_combined.index.week, y=AQI_combined['AQI_UrbanaOH'],
                hue='AQI_UrbanaOH_c', palette=colormap, alpha=0.8)
# Out:
# /var/folders/_m/f21vn7kj1b38wtjf1qn7m6kh0000gq/T/ipykernel_32459/2211319027.py:1: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series.  To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   sns.scatterplot(data=AQI_combined, x=AQI_combined.index.week, y=AQI_combined['AQI_UrbanaOH'],
# <AxesSubplot:xlabel='reading_datestamp', ylabel='AQI_UrbanaOH'>

# %%
from datetime import datetime as dt
import seaborn as sns
sns.set_context("notebook", font_scale=1)
sns.set(rc={'figure.figsize':(15,8.27)})
left = dt(2021,9,1)
right = dt(2021,11,30)
ax = sns.lineplot(data=AQI_combined[['combAQI', 'AQI_UrbanaOH','AQI_Urbana']], palette = ['red', 'black','purple'], alpha=0.6)
#ax = sns.lineplot(data=df_champaign[['pm2.5_Champaign']], palette = ['brown'], alpha=0.6)
ax.set_xlabel('AQI Comparison - AQMesh vs Purple Air', fontsize=10)
ax.set_xlim(left, right)
# Out:
# (18871.0, 18961.0)

# %%
fig, axes = plt.subplots(nrows=1, ncols=3,figsize=(25,10))


axes[0].pie(AQI_combined.combAQI_c.value_counts(), 
        labels= AQI_combined.combAQI_c.unique(),
        colors=['yellow', 'orange', 'red', 'green', 'purple'], autopct='%1.1f%%', pctdistance=1.2);
axes[1].pie(AQI_combined.AQI_UrbanaOH_c.value_counts(), 
        labels= AQI_combined.AQI_UrbanaOH_c.unique(),
        colors=['yellow', 'orange', 'red', 'green', 'purple'], autopct='%1.1f%%', pctdistance=1.2);
axes[2].pie(AQI_combined.AQI_Urbana_c.value_counts(), 
        labels= AQI_combined.AQI_Urbana_c.unique(),
        colors=['yellow', 'orange', 'red', 'green', 'purple'], autopct='%1.1f%%', pctdistance=1.2);
plt.title('AQI % for UIUC Sensor');
plt.title('AQI % for UIUC Sensor');

# %%
from datetime import datetime as dt
import seaborn as sns
sns.set_context("notebook", font_scale=1,rc={'figure.figsize':(18,6)})
left = dt(2021,9,1)
right = dt(2021,9,30)
ax = sns.lineplot(data=merged[['pm2_5_prescale', 'pm2.5_UrbanaOH','pm2.5_Urbana']], palette = ['navy', 'black','purple'], alpha=0.6)
ax = sns.lineplot(data=df_champaign[['pm2.5_Champaign']], palette = ['brown'], alpha=0.6)
ax.set_xlabel('AQMesh vs Purple Air', fontsize=10)
ax.set_xlim(left, right)
# Out:
# (18871.0, 18900.0)

# %%
#### Other stuff

# %%
#Lets get daily values to plot
df4= merged.groupby(np.arange(len(merged))//96).mean()
df4
# Out:
#     co_prescaled  CO2_prescaled  no_prescaled  no2_prescaled  o3_prescaled  \
# 0     286.725521     411.269896      6.415729       6.958021     26.562708
# 1     299.467604     410.089375      6.174792       6.762292     26.329583
# 2     313.994687     423.826042      9.386979       5.363333     14.815104
# 3     282.066146     415.100833      3.879271       7.137708     27.327708
# 4     286.465521     414.439375     13.467708       9.407708     28.363021
# ..           ...            ...           ...            ...           ...
# 84    418.651563     774.838021      0.195104      12.186979     31.302292
# 85    411.594792     772.523750      0.697188      12.806771     25.091250
# 86    395.604167     777.233438      1.644583       9.973229     26.651042
# 87    410.443854     773.978125      1.091042      15.145208     32.595417
# 88    367.485595     774.186905      2.483690      12.483095     25.619048
#
#     pm1_prescale  pm2_5_prescale  pm4_prescale  pm10_prescale  \
# 0       4.896979        6.655000      7.913229      10.094167
# 1       5.718021        7.458750      8.677292      10.563750
# 2       6.971146        9.126354     10.872083      12.339271
# 3       4.204687        5.743021      6.851354       9.103750
# 4       6.741250        8.545625      9.521354      11.155521
# ..           ...             ...           ...            ...
# 84      0.960104        1.845208      2.646250       5.428542
# 85      2.189062        3.405208      4.374688       6.597812
# 86      3.304167        4.903854      6.185729       9.916458
# 87      1.068229        2.228438      3.203542       6.088750
# 88      2.566429        4.028810      5.284643       9.457024
#
#     pm_total_prescale  pm_tpc_prescale  nox_prescaled  temperature_f  \
# 0           10.095104         2.663750      12.758854      72.401042
# 1           10.568229         3.070937      13.639167      71.135417
# 2           12.344062         3.736875      14.745521      68.345833
# 3            9.104687         2.322396      11.016979      73.851042
# 4           11.156354         3.542708      22.875417      77.969792
# ..                ...              ...            ...            ...
# 84           5.448021         0.708229      12.382083      27.288542
# 85           6.598125         1.315312      13.503958      34.561458
# 86           9.991250         1.891667      11.617812      37.294792
# 87           6.089375         0.783229      16.236250      34.048958
# 88           9.511667         1.537738      14.966786      42.579762
#
#       pressure   humidity  pm2.5_UrbanaOH  pm2.5_Urbana
# 0   991.905208  57.272917        8.404418      8.404418
# 1   989.088542  66.889583        9.513302      9.513302
# 2   985.207292  82.271875       12.865941     12.865941
# 3   987.305208  59.314583        6.321708      6.321708
# 4   986.236458  61.846875       12.732135     12.732135
# ..         ...        ...             ...           ...
# 84  997.418750  64.828125        3.190372      3.190372
# 85  987.276042  69.758333        7.285917      7.285917
# 86  989.673958  66.848958       15.370141     15.370141
# 87  992.194792  58.784375        4.830645      4.830645
# 88  987.991667  65.197619       11.345200     11.345200
#
# [89 rows x 17 columns]

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8,6))
ax = plt.axes()
  
x = list(range(1, 91))
# ax.plot(x, df4['pm2_5_prescale'].tolist(), label="PM2.5")
ax.plot(x, df4['CO2_prescaled'].tolist(), label="CO2")
#ax.plot(x, df4['co_prescaled'].tolist(), label="CO")
# ax.plot(x, df4['no_prescaled'].tolist(), label="NO")
# ax.plot(x, df4['no2_prescaled'].tolist(), label="NO2")
# ax.plot(x, df4['o3_prescaled'].tolist(), label="Ozone")
# ax.plot(x, df4['temperature_f'].tolist(), label="Temp F")
#ax.plot(x, df4['pressure'].tolist(), label="Pressure")
ax.plot(x, df4['humidity'].tolist(), label="Humidity")
plt.xlabel("Days (1-90)")
#plt.ylabel("PM 2.5 Val in PPB")
plt.legend(title="Legend")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/_m/f21vn7kj1b38wtjf1qn7m6kh0000gq/T/ipykernel_32459/3529471810.py in <module>
#       5 x = list(range(1, 91))
#       6 # ax.plot(x, df4['pm2_5_prescale'].tolist(), label="PM2.5")
# ----> 7 ax.plot(x, df4['CO2_prescaled'].tolist(), label="CO2")
#       8 #ax.plot(x, df4['co_prescaled'].tolist(), label="CO")
#       9 # ax.plot(x, df4['no_prescaled'].tolist(), label="NO")
#
# /opt/anaconda3/envs/dataviz/lib/python3.9/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
#    1634             self.add_line(line)
#
# /opt/anaconda3/envs/dataviz/lib/python3.9/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# /opt/anaconda3/envs/dataviz/lib/python3.9/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     496
#     497         if x.shape[0] != y.shape[0]:
# --> 498             raise ValueError(f"x and y must have same first dimension, but "
#     499                              f"have shapes {x.shape} and {y.shape}")
#     500         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (90,) and (89,)

# %%
df4= df3.groupby(np.arange(len(df3))//96).mean()
df4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/_m/f21vn7kj1b38wtjf1qn7m6kh0000gq/T/ipykernel_32459/769888480.py in <module>
# ----> 1 df4= df3.groupby(np.arange(len(df3))//96).mean()
#       2 df4
#
# NameError: name 'df3' is not defined
